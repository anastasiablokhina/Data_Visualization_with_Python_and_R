# %% [markdown]
# <a href="https://colab.research.google.com/github/anastasiablokhina/Data_Visualization_with_Python_and_R/blob/main/ML_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from google.colab import files
import matplotlib
import matplotlib.pyplot as plt
df = pd.read_csv('/content/72_36.csv', header=None)
df
# Out:
#             0          1          2          3          4          5  \
# 0   -7.551127 -16.501883  12.214029  -4.532918   7.195725 -10.695086
# 1   15.332258  -2.873288 -18.918645 -19.692909   9.338751  14.829184
# 2  -11.447178 -12.150761 -18.801647 -24.051650  15.213106  18.650944
# 3   16.922389  -4.922460 -21.959687 -19.735653   9.871696  15.691369
# 4   13.683867  -2.109327 -20.939583 -18.912884   7.441524  13.049203
# 5   -7.650408 -15.288996  13.691478  -7.234911  11.032896 -10.026850
# 6   17.153127  -1.646504 -21.185940 -20.126542  10.906075  15.481474
# 7   17.572495  -3.848517 -20.552760 -18.625220   8.494428  14.772499
# 8   -7.343882 -17.910808  10.043447  -6.692580   8.059758  -8.862623
# 9   -7.060784 -18.117843  14.917667  -5.327512   6.282496  -8.642371
# 10 -21.539976   7.653408   2.700571  -6.055936  -3.761794   2.084143
# 11  -7.602479  22.962942  -7.152070 -13.894589  -3.713878   8.235191
# 12  -8.776234 -16.251322  11.083312  -3.971506   9.026561  -8.788845
# ...

# %%
#Введите координату первого объекта относительно первой главной компоненты.
#Введите координату первого объекта относительно второй главной компоненты.
pca = PCA(n_components=2, svd_solver='full')
X = PCA(svd_solver = 'full', n_components = 2).fit_transform(df)
X[0]
# Out:
# array([ 21.5685525 , -20.11266413])

# %%
#Введите долю объясненной дисперсии при использовании первых двух главных компонент.
explained_variance = np.cumsum(pca.explained_variance_ratio_)
explained_variance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5c03a6e84cd7> in <module>()
#       1 #Введите долю объясненной дисперсии при использовании первых двух главных компонент.
# ----> 2 explained_variance = np.cumsum(pca.explained_variance_ratio_)
#       3 explained_variance
#
# AttributeError: 'PCA' object has no attribute 'explained_variance_ratio_'

# %%
#Какое минимальное количество главных компонент необходимо использовать, чтобы доля объясненной дисперсии превышала 0.85. Введите целое неотрицательное число

# %%
#Какое количество групп объектов можно выделить, если использовать только первые две главных компоненты?
